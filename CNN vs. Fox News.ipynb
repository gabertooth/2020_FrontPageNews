# %% [markdown]
# # THE MEDIA

# %% [markdown]
# The following sources will be used (random order):
#
# 1. Wall Street Journal
# 2. CNN
# 3. Fox News
# 4. Reuters
# 5. Washington Post
# 6. New York Times
# 7. Atlantic
# 8. Bloomberg
# 9. Huff Post
# 10. Buzz Feed

# %% [markdown]
# Wayback Machine
#
# -Look into Summary can do possible piece on complexity of the websites comparing them

# %% [markdown]
# ## CNN vs. Fox News

# %% [markdown]
# First we will look into comparing two very polarizing opposite news congolomerates. Fox News vs. CNN, a showdown for the ages. For those that are not familiar, CNN is fake news central as Trump calls it. While Fox News is a very 100 percent accurate reputable source.
#
# I myself find both publications leaning too far each of their respective ways. Below is a graphic showing some news websites

# %%
from selenium import webdriver #Selenium web driver
from selenium.webdriver.common.keys import Keys #Selenium wkeys
from bs4 import BeautifulSoup #BeatifulSoup for webscraping
import pandas as pd #Pandas dataframes and etc.

# %% [markdown]
# ### CNN

# %%
driver= webdriver.Chrome(executable_path=r'C:\Users\GBLS\Desktop\FakeNews\2020_FrontPageNews\chromedriver')
url_CNN= 'https://web.archive.org/web/*/cnn.com'

driver.get(url_CNN)

# %%
CNN_html= driver.page_source

CNN_soup= BeautifulSoup(CNN_html, 'html.parser')

# %%
CNN_soup.prettify
# Out:
# <bound method Tag.prettify of <html lang="en"><head><style type="text/css">svg:not(:root).svg-inline--fa {
#   overflow: visible;
# }
#
# .svg-inline--fa {
#   display: inline-block;
#   font-size: inherit;
#   height: 1em;
#   overflow: visible;
#   vertical-align: -0.125em;
# }
# .svg-inline--fa.fa-lg {
#   vertical-align: -0.225em;
# }
# .svg-inline--fa.fa-w-1 {
#   width: 0.0625em;
# }
# .svg-inline--fa.fa-w-2 {
#   width: 0.125em;
# }
# .svg-inline--fa.fa-w-3 {
#   width: 0.1875em;
# }
# .svg-inline--fa.fa-w-4 {
#   width: 0.25em;
# }
# .svg-inline--fa.fa-w-5 {
#   width: 0.3125em;
# }
# .svg-inline--fa.fa-w-6 {
#   width: 0.375em;
# }
# .svg-inline--fa.fa-w-7 {
#   width: 0.4375em;
# }
# .svg-inline--fa.fa-w-8 {
#   width: 0.5em;
# }
# .svg-inline--fa.fa-w-9 {
#   width: 0.5625em;
# }
# .svg-inline--fa.fa-w-10 {
#   width: 0.625em;
# }
# .svg-inline--fa.fa-w-11 {
#   width: 0.6875em;
# }
# .svg-inline--fa.fa-w-12 {
#   width: 0.75em;
# }
# .svg-inline--fa.fa-w-13 {
# ...

# %%
CNN_links= CNN_soup.find_all('a')

# %%
CNN=[]
for x in CNN_links:
    if 'cnn' in x['href']:
        CNN.append(x['href'])

# %%
CNN_full_url=[]
for x in CNN:
    CNN_full_url.append('https://web.archive.org'+ x)

# %%
CNN_full_url[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-690ba64478ad> in <module>
# ----> 1 CNN_full_url[:5]
#
# NameError: name 'CNN_full_url' is not defined

# %%
jan=CNN_full_url[6:37]
feb=CNN_full_url[37:65]
mar=CNN_full_url[65:96]
apr=CNN_full_url[96:126]
may=CNN_full_url[126:157]
jun=CNN_full_url[157:187]

# %%
driver= webdriver.Chrome(executable_path=r'C:\Users\GBLS\Desktop\FakeNews\2020_FrontPageNews\chromedriver')
driver.get('https://web.archive.org/web/20200616022826/https://www.cnn.com/')
html=driver.page_source

# %%
###Code below is good for webscraping

# %%
import time
# driver= webdriver.Chrome(executable_path=r'C:\Users\GBLS\Desktop\FakeNews\2020_FrontPageNews\chromedriver')
CNN_headline_data=[]
date=[]
counter=0
    
for link in jan:
    counter+=1
    driver.get(str(link))
    html=driver.page_source

    soup= BeautifulSoup(html, 'html.parser')

    for div in soup.findAll('span','cd__headline-text'):
        CNN_headline_data.append(div.text)
        date.append(str(link)[28:36])
    CNN_headline_data.append(soup.find('h2'))
    date.append(str(link)[28:36])
    counter+=1
    if counter%15==0:
        time.sleep(300)
df_CNN_Jan= pd.DataFrame({'Date':date, 'Text':CNN_headline_data})

# %%
df_CNN_Jan.to_csv('CNN_Jan')

# %%
# driver= webdriver.Chrome(executable_path=r'C:\Users\GBLS\Desktop\FakeNews\2020_FrontPageNews\chromedriver')
CNN_headline_data=[]
date=[]
counter=0
    
for link in mar:
    counter+=1
    driver.get(str(link))
    html=driver.page_source

    soup= BeautifulSoup(html, 'html.parser')

    for div in soup.findAll('span','cd__headline-text'):
        CNN_headline_data.append(div.text)
        date.append(str(link)[28:36])
    CNN_headline_data.append(soup.find('h2'))
    date.append(str(link)[28:36])
    counter+=1
    if counter%15==0:
        time.sleep(300)
df_CNN_Mar= pd.DataFrame({'Date':date, 'Text':CNN_headline_data})

# %%
df_CNN_Mar.to_csv('CNN_Mar')

# %%
# driver= webdriver.Chrome(executable_path=r'C:\Users\GBLS\Desktop\FakeNews\2020_FrontPageNews\chromedriver')
CNN_headline_data=[]
date=[]
counter=0
    
for link in feb:
    counter+=1
    driver.get(str(link))
    html=driver.page_source

    soup= BeautifulSoup(html, 'html.parser')

    for div in soup.findAll('span','cd__headline-text'):
        CNN_headline_data.append(div.text)
        date.append(str(link)[28:36])
    CNN_headline_data.append(soup.find('h2'))
    date.append(str(link)[28:36])
    counter+=1
    if counter%15==0:
        time.sleep(300)
df_CNN_feb= pd.DataFrame({'Date':date, 'Text':CNN_headline_data})

# %%
df_CNN_feb.to_csv('CNN_feb')

# %%
CNN_headline_data=[]
date=[]
counter=0
    
for link in apr:
    counter+=1
    driver.get(str(link))
    html=driver.page_source

    soup= BeautifulSoup(html, 'html.parser')

    for div in soup.findAll('span','cd__headline-text'):
        CNN_headline_data.append(div.text)
        date.append(str(link)[28:36])
    CNN_headline_data.append(soup.find('h2'))
    date.append(str(link)[28:36])
    counter+=1
    if counter%15==0:
        time.sleep(300)
df_CNN_apr= pd.DataFrame({'Date':date, 'Text':CNN_headline_data})

# %%
df_CNN_apr.to_csv('CNN_apr')

# %%
CNN_headline_data=[]
date=[]
counter=0
    
for link in may:
    counter+=1
    driver.get(str(link))
    html=driver.page_source

    soup= BeautifulSoup(html, 'html.parser')

    for div in soup.findAll('span','cd__headline-text'):
        CNN_headline_data.append(div.text)
        date.append(str(link)[28:36])
    CNN_headline_data.append(soup.find('h2'))
    date.append(str(link)[28:36])
    counter+=1
    if counter%15==0:
        time.sleep(300)
df_CNN_may= pd.DataFrame({'Date':date, 'Text':CNN_headline_data})

# %%
df_CNN_may
# Out:
#           Date                                               Text
# 0     20200430                                      Vaccine trial
# 1     20200430                                         Remdesivir
# 2     20200430                              Unemployment benefits
# 3     20200430                                 Reopening guidance
# 4     20200430                                       Disney masks
# ...        ...                                                ...
# 2211  20200530      Top deals this weekend: Adidas, Cricut & more
# 2212  20200530  Warm-weather loungewear to upgrade your WFH un...
# 2213  20200530  From stylish to silly: face masks for every pe...
# 2214  20200530  Shop brands offering discounts for front-line ...
# 2215  20200530               [Clashes erupt again in many cities]
#
# [2216 rows x 2 columns]

# %%
df_CNN_may.to_csv('CNN_May')

# %%
import time 
CNN_headline_data=[]
date=[]
counter=0
    
for link in jun:
    counter+=1
    driver.get(str(link))
    html=driver.page_source

    soup= BeautifulSoup(html, 'html.parser')

    for div in soup.findAll('span','cd__headline-text'):
        CNN_headline_data.append(div.text)
        date.append(str(link)[28:36])
    CNN_headline_data.append(soup.find('h2'))
    date.append(str(link)[28:36])
    counter+=1
    if counter%15==0:
        time.sleep(300)
df_CNN_jun= pd.DataFrame({'Date':date, 'Text':CNN_headline_data})

# %%
df_CNN_jun.to_csv('CNN_jun',index=False)

# %%
driver.get('https://web.archive.org/web/20190101000000*/cnn.com')

# %%
CNN_html= driver.page_source
CNN_soup= BeautifulSoup(CNN_html, 'html.parser')

# %%
CNN_links= CNN_soup.find_all('a')

# %%
CNN_links
# Out:
# [<a href="http://blog.archive.org/2020/06/10/temporary-national-emergency-library-to-close-2-weeks-early-returning-to-traditional-controlled-digital-lending/" rel="nofollow">See what’s new with book lending at the Internet Archive</a>,
#  <a class="navia-link home" href="https://archive.org" target="_top" title="Home">
#  <span class="iconochive-logo"></span>
#  <div class="archive-wordmark">
#  <img alt="Internet Archive Logo" src="https://archive.org/images/wordmark-narrow-spacing.svg"/>
#  </div>
#  </a>,
#  <a class="navia-link web" data-top-kind="web" href="https://archive.org/web/" target="_top" title="Web"><span aria-hidden="true" class="iconochive-web"></span><span>web</span></a>,
#  <a class="navia-link texts" data-top-kind="texts" href="https://archive.org/details/texts" target="_top" title="Texts"><span aria-hidden="true" class="iconochive-texts"></span><span>books</span></a>,
# ...

# %%
dude=[]
for x in CNN_links:
    if 'cnn' in x['href']:
        dude.append(x['href'])

# %%
CNN_2019_links= []
for x in dude:
    CNN_2019_links.append('https://web.archive.org'+ x)

# %%
CNN_2019_links= CNN_2019_links[6:]

# %%
for link in CNN_2019_links:
    counter+=1
    driver.get(str(link))
    html=driver.page_source

    soup= BeautifulSoup(html, 'html.parser')

    for div in soup.findAll('span','cd__headline-text'):
        CNN_headline_data.append(div.text)
        date.append(str(link)[28:36])
    CNN_headline_data.append(soup.find('h2'))
    date.append(str(link)[28:36])
    counter+=1
    if counter%15==0:
        time.sleep(300)

# %%
df_CNN_2019= pd.DataFrame({'Date':date, 'Text':CNN_headline_data}) 
df_CNN_2019.to_csv('CNN_2019')

# %%
df=pd.read_csv('CNN_2019')

# %%
df.drop(['Unnamed: 0','Unnamed: 3'], axis=1, inplace=True)

# %%
df.to_csv('CNN_2019_Updated')

# %%
CNN_missing=['/web/20191222/cnn.com',
 '/web/20191223/cnn.com',
 '/web/20191224/cnn.com',
 '/web/20191225/cnn.com',
 '/web/20191226/cnn.com',
 '/web/20191227/cnn.com',
 '/web/20191228/cnn.com',
 '/web/20191229/cnn.com',
 '/web/20191230/cnn.com',
 '/web/20191231/cnn.com']

# %%
CNN_missing_links=[]

# %%
for x in CNN_missing:
    CNN_missing_links.append('https://web.archive.org'+ x)

# %%
CNN_headline_data=[]
date=[]

# %%
driver= webdriver.Chrome(executable_path=r'C:\Users\GBLS\Desktop\FakeNews\2020_FrontPageNews\chromedriver')
for link in CNN_missing_links:
    counter+=1
    driver.get(str(link))
    html=driver.page_source

    soup= BeautifulSoup(html, 'html.parser')

    for div in soup.findAll('span','cd__headline-text'):
        CNN_headline_data.append(div.text)
        date.append(str(link)[28:36])
    CNN_headline_data.append(soup.find('h2'))
    date.append(str(link)[28:36])
    counter+=1
    if counter%15==0:
        time.sleep(300)

# %%
CNN_2019_missing=pd.DataFrame({'Date': date, 'Text': CNN_headline_data})

# %%
CNN_2019_Updated= pd.read_csv('CNN_2019_Updated')

# %%
CNN_2019_Updated.drop('Unnamed: 0',inplace=True, axis=1)

# %%
df_CNN_2019=pd.concat([CNN_2019_Updated, CNN_2019_missing])

# %%
df_CNN_2019.reset_index(drop=True, inplace=True)

# %%
df_CNN_2019.to_csv('CNN-2019', index=False)

# %%
pd.read_csv('CNN-2019')
# Out:
#            Date                                               Text
# 0      20190101  Trump tweets Gen. Stanley McChrystal has a 'bi...
# 1      20190101                 See interview with retired general
# 2      20190101                   McChrystal calls Trump dishonest
# 3      20190101  Perspectives: America faces a leadership crisi...
# 4      20190101   Analysis: Trump keeps insulting military members
# ...         ...                                                ...
# 36715  20191231           Merriam-Webster reveals word of the year
# 36716  20191231                     2019's best red carpet moments
# 36717  20191231          Netflix's most-popular titles of the year
# 36718  20191231                  19 destinations that defined 2019
# 36719  20191231  <h2 class="banner-text screaming-banner-text b...
#
# [36720 rows x 2 columns]

# %% [markdown]
# ### Fox News

# %%
from selenium import webdriver #Selenium web driver
from selenium.webdriver.common.keys import Keys #Selenium wkeys
from bs4 import BeautifulSoup #BeatifulSoup for webscraping
import pandas as pd #Pandas dataframes and etc.

# %%
driver.get('https://web.archive.org/web/*/http://foxnews.com/')

# %%
fox_page= driver.page_source

# %%
soup = BeautifulSoup(fox_page, 'html.parser')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <html lang="en"><head><style type="text/css">svg:not(:root).svg-inline--fa {
#   overflow: visible;
# }
#
# .svg-inline--fa {
#   display: inline-block;
#   font-size: inherit;
#   height: 1em;
#   overflow: visible;
#   vertical-align: -0.125em;
# }
# .svg-inline--fa.fa-lg {
#   vertical-align: -0.225em;
# }
# .svg-inline--fa.fa-w-1 {
#   width: 0.0625em;
# }
# .svg-inline--fa.fa-w-2 {
#   width: 0.125em;
# }
# .svg-inline--fa.fa-w-3 {
#   width: 0.1875em;
# }
# .svg-inline--fa.fa-w-4 {
#   width: 0.25em;
# }
# .svg-inline--fa.fa-w-5 {
#   width: 0.3125em;
# }
# .svg-inline--fa.fa-w-6 {
#   width: 0.375em;
# }
# .svg-inline--fa.fa-w-7 {
#   width: 0.4375em;
# }
# .svg-inline--fa.fa-w-8 {
#   width: 0.5em;
# }
# .svg-inline--fa.fa-w-9 {
#   width: 0.5625em;
# }
# .svg-inline--fa.fa-w-10 {
#   width: 0.625em;
# }
# .svg-inline--fa.fa-w-11 {
#   width: 0.6875em;
# }
# .svg-inline--fa.fa-w-12 {
#   width: 0.75em;
# }
# .svg-inline--fa.fa-w-13 {
# ...

# %%
FOX_links=soup.find_all('a')

# %%
FOX=[]
for x in FOX_links:
    if 'foxnews' in x['href']:
        FOX.append(x['href'])

# %%
FOX
# Out:
# ['/web/collections/*/http://foxnews.com/',
#  '/web/changes/http://foxnews.com/',
#  '/details/http://foxnews.com/',
#  '/web/sitemap/http://foxnews.com/',
#  '/web/19961022175132/http://foxnews.com/',
#  '/web/20200630080544/http://foxnews.com/',
#  '/web/20200101/http://foxnews.com/',
#  '/web/20200102/http://foxnews.com/',
#  '/web/20200103/http://foxnews.com/',
#  '/web/20200104/http://foxnews.com/',
#  '/web/20200105/http://foxnews.com/',
#  '/web/20200106/http://foxnews.com/',
#  '/web/20200107/http://foxnews.com/',
#  '/web/20200108/http://foxnews.com/',
#  '/web/20200109/http://foxnews.com/',
#  '/web/20200110/http://foxnews.com/',
#  '/web/20200111/http://foxnews.com/',
#  '/web/20200112/http://foxnews.com/',
#  '/web/20200113/http://foxnews.com/',
#  '/web/20200114/http://foxnews.com/',
#  '/web/20200115/http://foxnews.com/',
#  '/web/20200116/http://foxnews.com/',
#  '/web/20200117/http://foxnews.com/',
#  '/web/20200118/http://foxnews.com/',
# ...

# %%
FOX_full_link= []
for x in FOX:
    FOX_full_link.append('https://web.archive.org' + x)

# %%
FOX_2020_links=FOX_full_link

# %% [markdown]
# TEST WORK SPACE

# %%
jan=FOX_2020_links[6:37]
feb=FOX_2020_links[37:66]
mar=FOX_2020_links[66:97]
apr=FOX_2020_links[97:127]
may=FOX_2020_links[127:157]
jun=FOX_2020_links[158:188]

# %%
import requests 
import urllib

# %%
# driver= webdriver.chromedriver(executable_path=r'C:\Users\GBLS\Desktop\FakeNews\2020_FrontPageNews\chromedriver')
FOX_news_headline_data= []
date= []
# driver= webdriver.Chrome(r'/Users/gabrielblatstein/Downloads/chromedriver')
for link in jan:
    r= requests.get(link)
    html= r.text
    soup= BeautifulSoup(html, 'html.parser')

    for h2 in soup.find_all('h2'):
        FOX_news_headline_data.append(h2.text)
        date.append(str(link)[28:36])
df_FOX_jan= pd.DataFrame({'Date':date, 'Text':FOX_news_headline_data})

# %%
df_FOX_jan.to_csv('FOX_Jan', index=False)

# %%
FOX_news_headline_data= []
date= []
# driver= webdriver.Chrome(r'/Users/gabrielblatstein/Downloads/chromedriver')
for link in feb:
    r= requests.get(link)
    html= r.text
    soup= BeautifulSoup(html, 'html.parser')

    for h2 in soup.find_all('h2'):
        FOX_news_headline_data.append(h2.text)
        date.append(str(link)[28:36])
df_FOX_feb= pd.DataFrame({'Date':date, 'Text':FOX_news_headline_data})

# %%
df_FOX_feb.to_csv('FOX_Feb', index= False)

# %%
FOX_news_headline_data= []
date= []
# driver= webdriver.Chrome(r'/Users/gabrielblatstein/Downloads/chromedriver')
for link in mar:
    r= requests.get(link)
    html= r.text
    soup= BeautifulSoup(html, 'html.parser')

    for h2 in soup.find_all('h2'):
        FOX_news_headline_data.append(h2.text)
        date.append(str(link)[28:36])
df_FOX_mar= pd.DataFrame({'Date':date, 'Text':FOX_news_headline_data})

# %%
df_FOX_mar.to_csv('FOX_Mar', index= False)

# %%
FOX_news_headline_data= []
date= []
# driver= webdriver.Chrome(r'/Users/gabrielblatstein/Downloads/chromedriver')
for link in apr:
    r= requests.get(link)
    html= r.text
    soup= BeautifulSoup(html, 'html.parser')

    for h2 in soup.find_all('h2'):
        FOX_news_headline_data.append(h2.text)
        date.append(str(link)[28:36])
df_FOX_apr= pd.DataFrame({'Date':date, 'Text':FOX_news_headline_data})

# %%
df_FOX_apr.to_csv('FOX_Apr', index=False)

# %%
FOX_news_headline_data= []
date= []
# driver= webdriver.Chrome(r'/Users/gabrielblatstein/Downloads/chromedriver')
for link in may:
    r= requests.get(link)
    html= r.text
    soup= BeautifulSoup(html, 'html.parser')

    for h2 in soup.find_all('h2'):
        FOX_news_headline_data.append(h2.text)
        date.append(str(link)[28:36])
df_FOX_may= pd.DataFrame({'Date':date, 'Text':FOX_news_headline_data})

# %%
df_FOX_may.to_csv('FOX_may', index=False)

# %%
FOX_news_headline_data= []
date= []
# driver= webdriver.Chrome(r'/Users/gabrielblatstein/Downloads/chromedriver')
for link in jun:
    r= requests.get(link)
    html= r.text
    soup= BeautifulSoup(html, 'html.parser')

    for h2 in soup.find_all('h2'):
        FOX_news_headline_data.append(h2.text)
        date.append(str(link)[28:36])
df_FOX_jun= pd.DataFrame({'Date':date, 'Text':FOX_news_headline_data})

# %%
df_FOX_jun.to_csv('FOX_jun')

# %% [markdown]
# Now I would like to get all of Fox News' homepage headline and subheadings for the entire year of 2019

# %%
driver.get('https://web.archive.org/web/20190101000000*/http://www.foxnews.com/')

# %%
html=driver.page_source

# %%
soup=BeautifulSoup(html, 'html.parser')

# %%
soup.find_all('a')
# Out:
# [<a href="http://blog.archive.org/2020/06/10/temporary-national-emergency-library-to-close-2-weeks-early-returning-to-traditional-controlled-digital-lending/" rel="nofollow">See what's new with book lending at the Internet Archive</a>,
#  <a class="navia-link home" href="https://archive.org" target="_top" title="Home">
#  <span class="iconochive-logo"></span>
#  <div class="archive-wordmark">
#  <img alt="Internet Archive Logo" src="https://archive.org/images/wordmark-narrow-spacing.svg"/>
#  </div>
#  </a>,
#  <a class="navia-link web" data-top-kind="web" href="https://archive.org/web/" target="_top" title="Web"><span aria-hidden="true" class="iconochive-web"></span><span>web</span></a>,
#  <a class="navia-link texts" data-top-kind="texts" href="https://archive.org/details/texts" target="_top" title="Texts"><span aria-hidden="true" class="iconochive-texts"></span><span>books</span></a>,
# ...

# %%
links=[]
for x in soup.find_all('a'):
    if 'foxnews' in x['href']:
        links.append('https://web.archive.org' + x['href'])

# %%
fox_2019_links=links[6:]

# %%
fox_2019_links
# Out:
# ['https://web.archive.org/web/20190101/http://www.foxnews.com/',
#  'https://web.archive.org/web/20190102/http://www.foxnews.com/',
#  'https://web.archive.org/web/20190103/http://www.foxnews.com/',
#  'https://web.archive.org/web/20190104/http://www.foxnews.com/',
#  'https://web.archive.org/web/20190105/http://www.foxnews.com/',
#  'https://web.archive.org/web/20190106/http://www.foxnews.com/',
#  'https://web.archive.org/web/20190107/http://www.foxnews.com/',
#  'https://web.archive.org/web/20190108/http://www.foxnews.com/',
#  'https://web.archive.org/web/20190109/http://www.foxnews.com/',
#  'https://web.archive.org/web/20190110/http://www.foxnews.com/',
#  'https://web.archive.org/web/20190111/http://www.foxnews.com/',
#  'https://web.archive.org/web/20190112/http://www.foxnews.com/',
#  'https://web.archive.org/web/20190113/http://www.foxnews.com/',
#  'https://web.archive.org/web/20190114/http://www.foxnews.com/',
# ...

# %%
FOX_news_headline_data= []
date= []
# driver= webdriver.Chrome(r'/Users/gabrielblatstein/Downloads/chromedriver')
for link in fox_2019_links:
    r= requests.get(link)
    html= r.text
    soup= BeautifulSoup(html, 'html.parser')

    for h2 in soup.find_all('h2'):
        FOX_news_headline_data.append(h2.text)
        date.append(str(link)[28:36])
df_FOX_2019= pd.DataFrame({'Date':date, 'Text':FOX_news_headline_data})

# %%
df_FOX_2019[df_FOX_2019['Date']=='20190101']
# Out:
#          Date                                               Text
# 0    20190101        What changes to the minimum wage mean in US
# 1    20190101  Foundation closer to fundraising goal for Roni...
# 2    20190101                 Best cures for New Year's hangover
# 3    20190101      How Trump can finally drain the swamp in 2019
# 4    20190101  Terror investigation under way after stabbing ...
# ..        ...                                                ...
# 204  20190101  Goose found shot with arrow at California park...
# 205  20190101  Eagle lands on Notre Dame fans before start of...
# 206  20190101  'Selfie wrist' an emerging hazard of digital a...
# 207  20190101  Goose, gull that swallowed pills in California...
# 208  20190101  Texas man allegedly shoots wife's laptop becau...
#
# [209 rows x 2 columns]

# %%
df_FOX_2019
# Out:
#            Date                                               Text
# 0      20190101        What changes to the minimum wage mean in US
# 1      20190101  Foundation closer to fundraising goal for Roni...
# 2      20190101                 Best cures for New Year's hangover
# 3      20190101      How Trump can finally drain the swamp in 2019
# 4      20190101  Terror investigation under way after stabbing ...
# ...         ...                                                ...
# 77858  20191231  \nColorado man says 'I really suck at this' af...
# 77859  20191231  Texas boy sets front yard on fire after gettin...
# 77860  20191231  Pennsylvania woman who lit motor home on fire ...
# 77861  20191231  British lawyer claims he killed fox with baseb...
# 77862  20191231  Caesars casino in Canada sued by compulsive ga...
#
# [77863 rows x 2 columns]

# %%
df_FOX_2019.to_csv('Foxnews_2019', index=False)

# %% [markdown]
# # Combining Data to create 2020 DF's

# %% [markdown]
# I noticed I was missing some data from CNN, so I had to go back and webscrape the data. Below are the missing dates and I then concatenated the missing feb data with the feb saved csv.

# %%
missing_feb= ['https://web.archive.org/web/20200205/cnn.com', 
              'https://web.archive.org/web/20200206/cnn.com',
              'https://web.archive.org/web/20200207/cnn.com',
              'https://web.archive.org/web/20200208/cnn.com',
              'https://web.archive.org/web/20200209/cnn.com',
              'https://web.archive.org/web/20200210/cnn.com',
              'https://web.archive.org/web/20200211/cnn.com',
              'https://web.archive.org/web/20200212/cnn.com',
              'https://web.archive.org/web/20200213/cnn.com']

# %%
df_CNN_missing_feb= pd.read_csv('Missing_feb')

# %%
df_CNN_missing_feb=df_CNN_missing_feb.drop('Unnamed: 0', axis=1)

# %%
df_CNN_feb= pd.read_csv('CNN_feb')

# %%
df_CNN_feb= df_CNN_feb.drop('Unnamed: 0', axis=1)

# %%
df_CNN_feb= pd.concat([df_CNN_feb, df_CNN_missing_feb])

# %%
df_CNN_feb.reset_index(inplace=True, drop=True)

# %%
df_CNN_feb
# Out:
#           Date                                               Text
# 0     20200201                                     Vanessa Bryant
# 1     20200201                              Coronavirus in the US
# 2     20200201                                Black History Month
# 3     20200201                                             WeWork
# 4     20200201                                        Leila Janah
# ...        ...                                                ...
# 4016  20200213  We tried out the Galaxy Z Flip phone. Samsung ...
# 4017  20200213  London will use live facial recognition camera...
# 4018  20200213  Samsung takes second crack at a foldable smart...
# 4019  20200213    Opinion: Think 5G is exciting? Just wait for 6G
# 4020  20200213  <h2 class="banner-text screaming-banner-text b...
#
# [4021 rows x 2 columns]

# %%
df_CNN_feb.to_csv('CNN_feb')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-925b8929a2d1> in <module>
# ----> 1 df_CNN_feb.to_csv('CNN 2020/CNN_feb')
#
# NameError: name 'df_CNN_feb' is not defined

# %% [markdown]
# Now to load all of the csv files to put concatanate into one dataframe.

# %%
CNN_jan= pd.read_csv('CNN 2020/CNN_Jan')

# %%
CNN_feb= pd.read_csv('CNN 2020/CNN_feb')

# %%
CNN_mar= pd.read_csv('CNN 2020/CNN_Mar')

# %%
CNN_apr= pd.read_csv('CNN 2020/CNN_apr')

# %%
CNN_may= pd.read_csv('CNN 2020/CNN_may')

# %%
CNN_jun= pd.read_csv('CNN 2020/CNN_Jun')

# %%
CNN_news_2020= pd.concat([CNN_jan, CNN_feb, CNN_mar, CNN_apr, CNN_may, CNN_jun])

# %%
CNN_news_2020.reset_index(inplace=True)

# %%
CNN_news_2020.drop(['index'], axis=1, inplace=True)

# %%
CNN_news_2020.to_csv('CNN_2020',index=False)

# %% [markdown]
# Fox news

# %%
fox_news_2020=pd.concat([df_FOX_jan, df_FOX_feb, df_FOX_mar, df_FOX_apr, df_FOX_may, df_FOX_jun])

# %%
fox_news_2020.reset_index(inplace=True)

# %%
fox_news_2020=fox_news_2020.drop(['index'], axis=1)

# %%
fox_news_2020.to_csv('FOX_2020')

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# Now that we have the data for both Fox News and CNN media websites we need to clean the text data. The dataframes are organized in the same format as you can see below.
#
# Columns are as follows:
#     -Date
#     -Subheadings

# %%
# Out:
#        Date            Text
# 0  20200101   2020 new laws
# 1  20200101          Pope
# 2  20200101        Zoo fire
# 3  20200101   Stacy London
# 4  20200101  Richest person

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17995 entries, 0 to 17994
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    17995 non-null  int64
#  1   Text    17951 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 281.3+ KB

# %%
CNN_2020= pd.read_csv('CNN_2020', usecols=[1,2])
CNN_2020.head()
# Out:
#        Date            Text
# 0  20200101   2020 new laws
# 1  20200101          Pope
# 2  20200101        Zoo fire
# 3  20200101   Stacy London
# 4  20200101  Richest person

# %%
# Out:
#        Date                                               Text
# 0  20200101         'The Five' make their predictions for 2020
# 1  20200101                     The best of 'The Five' in 2019
# 2  20200101  Hate crimes at houses of worship up nearly 35 ...
# 3  20200101               US sending 750 troops to Middle East
# 4  20200101  Pompeo postpones trip to Ukraine after attack ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34539 entries, 0 to 34538
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    34539 non-null  int64
#  1   Text    34537 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 539.8+ KB

# %% [markdown]
# ## WSJ Trump vs. Obama Era

# %% [markdown]
# ## Bloomberg vs. Economist vs. Wall Street Journal

# %% [markdown]
# ## NYT vs. Atlantic vs. Washington Post vs. Reuters

# %% [markdown]
# ## COVID-19 Era
